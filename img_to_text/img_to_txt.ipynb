# %%
import pytesseract
import cv2
import numpy as np
from PIL import Image

img_path = '/home/praveen/Desktop/My-Projects/interview_p/imgs/inputs/image copy.png'

def extract_text_strong(image_path):
    # Read in OpenCV
    img = cv2.imread(image_path)

    # 1) Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # 2) Scale up aggressively (3x)
    scale_factor = 3
    gray = cv2.resize(gray, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_CUBIC)

    # 3) Sharpen edges
    kernel = np.array([[0, -1, 0],
                       [-1, 5,-1],
                       [0, -1, 0]])
    gray = cv2.filter2D(gray, -1, kernel)

    # 4) Adaptive threshold (smaller block size for thin fonts)
    thresh = cv2.adaptiveThreshold(gray, 255,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY, 15, 8)

    # 5) Morphological close (connect broken letters)
    kernel_morph = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
    morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel_morph)

    # 6) OCR with UI-friendly config
    config = r'--oem 3 --psm 11'  # sparse text, LSTM engine
    text = pytesseract.image_to_string(morph, config=config)

    return text

result = extract_text_strong(img_path)
print(result)
# Out:
# Xctivities
#
# ANI SOIPI
#
# S FF @ Ceam
#
# —
#
# iB
#
# *
#
# Backend Devel: x
#
# © PraveenGupta: x || 4, Contact Us
#
# x || [i Praveen Gupta: x || G imagetotext¢ x || fH (26) Linkedin
#
# x || +
#
# OQ (inarview prep) @ Explainscreens x || @ Average Selling x || (S| Internships|Jc x
#
# ¢
#
# ,
#
# I,
#
# bee
#
# €> 6 Ait
#
# %,
#
# =,
#
# | internshala.com/internship/detail/work-from-home-backend-development-internship-at-tailortalk1 750684671
#
# ®t
#
# Ey
#
# 3
#
# o}
#
# |
#
# we
#
# .
#
# 2 ( Relaunch to update 7
#
# a
#
# Backend Development - Internship
#
# © Applications are closed for this internship. Click here to browse more internships.
#
# Backend Development
#
# TailorTalk
#
# @ Work from home
#
# (@) START DATE
#
# (4 DURATION
#
# STIPEND
#
# 3 APPLY BY
#
# Immediately
#
# 6 Months
#
# & 15,000 - 18,000 /month
#
# 8 Jul’ 25
#
# © Posted 3 weeks ago
#
# ih Job offer upto ¥ 12LPA post internship
#
# ©? 1000+ applicants
#
# About the work from home job/internship
#
# Selected intern's day-to-day responsibilities include:
#
# 1. Building and maintaining backend APIs that power real-time Al sales agents across platforms such as WhatsApp and Instagram
#
# 2. Working with Al agents, databases, and event-driven systems to enable autonomous understanding and responses
#
# 3. Optimizing performance, scaling infrastructure, and contributing to the architecture of next-generation Al agent systems
#
# Skill(s) required
#
# FastAPl
#
# REST API
#
# Object Oriented Programming (OOP)
#
# Python
#
# System Design
#
# Earn certifications in these skills
#
# Learn AR/VR Using C#
#
# Learn Python
#
# Learn Voice App Development
#
# Who can apply
#
# Only those candidates can apply who:
#
# 1. are available for the work from home job/internship
#
# ts
#
# ooo
#
# a.
#
# ooo
#
# uy
#
# ooo
#
# ®
#
# xg)

# %%
import pytesseract
import cv2
import numpy as np

def extract_text_strong(image_path, use_whitelist=False, search_text=None):
    # Read in OpenCV
    img = cv2.imread(image_path)

    # 1) Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # 2) Scale up aggressively (3x)
    scale_factor = 3
    gray = cv2.resize(gray, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_CUBIC)

    # 3) Sharpen edges
    kernel = np.array([[0, -1, 0],
                       [-1, 5, -1],
                       [0, -1, 0]])
    gray = cv2.filter2D(gray, -1, kernel)

    # 4) Adaptive threshold (smaller block size for thin fonts)
    thresh = cv2.adaptiveThreshold(gray, 255,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY, 15, 8)

    # 5) Morphological close (connect broken letters)
    kernel_morph = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
    morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel_morph)

    # 6) OCR config
    config = r'--oem 3 --psm 11'  # Sparse text, LSTM
    if use_whitelist:
        whitelist_chars = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789₹$€.,:/%-+"
        config += f' -c tessedit_char_whitelist="{whitelist_chars}"'

    # 7) Run OCR
    text = pytesseract.image_to_string(morph, config=config)

    # 8) Optional text search
    if search_text is not None:
        found = search_text.lower() in text.lower()
        return text, found

    return text

result = extract_text_strong(img_path, True, 'praveen')
print(result)
# Out:
# ('Xctivities\n\nAugit220PM\n\nS6Osie\n\nContactUs\n\niB\n\n%\n\nOQ inariewprapExplainscreensx€AverageSellincxinternshipsJcxBackendDevelx€PraveenGupta:xd.\n\nxflPraveenGupta:xGimagetotextcx t 26Linkedinx l 1\n\no\n\nlinkedin.com/jobs/search-results/2keywords-data%20analystSoriginsJOBCOLLECTIONPAGESEARCHBUTTON\n\nEy\n\nTX,\n\n3\n\noF\n\nbee\n\nwe\n\n.\n\neorecat\n\n2 C Relaunchtoupdate:\n\na\n\nC23\n\nN\n\na\n\ni\n\nLa\n\nHag\n\nooo\n\nTryPremiumFor70\n\nCGaiESOssepotedComsony\n\nAl-poweredsearchisinbetav\n\n7results\n\n9GreaterAllahabadAreav\n\nHowpromotedjobsareranked\n\na\n\nOnlineDataAnalystY\n\nTELUSDigitalAlDataSolutions\n\ncTELUSDigitalAlDataSolutions\n\nOo\n\neee\n\nEe\n\nVaranasi,UttarPradesh,IndiaRemote\n\nViewed\n\nOnlineDataAnalyst9\n\nVaranasi,UttarPradesh,India-2weeksago-85peopleclickedapply\n\nOnlineDataAnalyst\n\nPromotedbyhirer-ResponsesmanagedoffLinkedIn\n\nEe\n\nTELUSDigitalAlDataSolutions\n\nJaunpur,UttarPradesh,IndiaRemote\n\n2weeksago\n\nOnlineDataAnalyst\n\nEe\n\nTELUSDigitalAlDataSolutions\n\nPrayagraj,UttarPradesh,IndiaRemote\n\n2weeksago\n\nYourprofilematchessomerequiredqualifications\n\nHomebasedOnlineDataAnalyst\n\nx\n\nShowmatchdetails\n\nEe\n\nPunjabi\n\nTELUSDigitalAlDataSolutions\n\nBETA-Isthisinformationhelpful\n\nSY\n\nGreaterAllahabadAreaRemote\n\n2weeksago\n\nAM-PMUMIS-Varanasi\n\nGetpersonalizedtipstostandouttohirers\n\nHYD\n\nre\n\nGMRHyderabadInternationalAirportLtd\n\nVaranasi,UttarPradesh,IndiaOn-site\n\nFindjobswhereyoureatopapplicantandtailoryourresumewiththehelpofAl.\n\n1weekago\n\nTryPremiumfor20\n\nAM-PMUMIS-Varanasi-13813\n\nGAR\n\nGMRGroup\n\nAboutthejob\n\nVaranasi,UttarPradesh,IndiaOn-site\n\n1weekago\n\nOnlineDataAnalyst-UrduIN\n\ne\n\nSiteSupervisor\n\nJobDescription:\n\ny.\n\nnntMDILCAD.\n\nAreyouadetail-orientedindividualwithapassionforresearchandagoodunderstandingof\n\n.\n\nGaefebclentsferGhissaardo\n\nnationalandlocalgeographyThisfreelanceopportunityallowsyoutoworkaty\n\nGb\n\nor\n\nandfromthecomfortofyourownhome.\n\nGa\n\nx e Messaging\n\niC\n\nSn\n\nSS\n\nooo\n\na.\n\nooo\n\no98\n\nuy\n\nooo\n\nxg\n\x0c', True)
